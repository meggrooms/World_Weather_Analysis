# %%
# Create a new set of 2,000 random latitudes and longitudes.

# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# One can only unzip a zipped tuple once before it is removed from the computer's memory. 
# Make sure to unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Starting URL for Weather Map API Call.
# url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(2.324584213967114, -159.73716760395578), (-65.40050624272999, -84.76450035748927), (66.84277449431116, -155.82977325986099), (65.71926689752908, 45.26742959917232), (14.836903002409485, 141.2921347349415), (-10.254757761149378, 44.44608715911912), (-62.497381926524845, -98.11854721175409), (-32.36293878416099, 54.19964428589515), (-17.837039468334908, -157.96862678647923), (-2.479347903882953, 160.60296890028923), (50.542371443567475, 165.63651148366858), (-69.35108905947054, 106.73561929189555), (5.250416835792208, -87.05951367729429), (62.10249715314782, -105.06345557887482), (75.00477421904117, -113.07494696154946), (-46.45722912433828, -29.15655849618318), (-79.74401258065814, -65.04068680819091), (87.05653823083313, 8.781893568882765), (-17.649405319381188, 66.46870075327223), (-44.33055405089581, 63.07746988685582), (40.64546479395861, 68.47913795636279), (-15.753305126422234, 27.27431183368003), (-60.50663989024026, -77.39319009712914), (-77.42558743479447, -91.95294603945881), (-3.403743611127922, -24.86509734822144), (-43.15766605014651, -118.20421026948759), (-27.449018467051594, -103.75021725485242), (25.37360974982711, -150.8334493775934), (2.756364625023366, -37.92680624058343), (-30.115843789312905, 89.282343136549), (15.721500776050334, 6.659573471159888), (-4.954529869058987, -29.867574091435245), (-88.24391453264667, 10.149668419887774), (65.7389397245527, 66.91002422521456), (-37.731141867162, -160.8801826988638), (85.21262502690016, -75.04315319605713), (82.45532947546849, -99.31247050772983), (58.685632026873805, -141.6600650004147), (65.61074453579573, -141.0147083580362), (-81.83419884522908, 6.497310925088584), (0.942897398640028, 141.30651334075094), (-73.56772009163534, -101.87894381118832), (-49.3598547951781, 75.13275258013957), (33.257090543753165, 76.35477388485509), (-38.48283603681894, 91.0000696465562), (71.46807211483377, 55.580011786452275), (77.73775117707748, 61.54652449887729), (4.173679678804774, 66.92179692141028), (27.50336912878926, 131.11297939024695), (-66.21182237792752, 148.1346387784003), (10.295884713710336, -59.500204488251356), (-8.886575647073371, 14.801677968203052), (31.927675391559347, -37.945667119067565), (-24.602439430548515, -78.74836348946376), (76.84161224860915, -20.88681081943369), (2.084908616347363, -25.23636458524581), (48.64933793198429, -72.4784125255048), (-47.477774426326086, -126.94000521710791), (-17.089926769873287, -160.67753817666235), (61.568584909136746, -130.96477118758037), (56.31218780442137, 163.3883373109261), (0.8777570295909669, -154.20285900501622), (38.08892554358718, -56.10490051996348), (49.61608994617103, -24.158794490969882), (-46.39142075064539, 104.69083793303412), (-67.53810269228488, 66.60938695149673), (-7.590946161381851, -153.3910835704059), (34.80144500439572, 59.691047131651146), (10.082533272388304, 75.67332992605046), (29.108305621341486, 148.26984317880232), (-69.01683434323498, 105.80270536498091), (0.34086628702257826, 114.41276439981317), (61.18804049945541, 159.40412445689202), (-39.83738581087727, 69.83324540652413), (-40.86554550549469, 98.8863254150724), (-59.55590158316611, -49.19820155108016), (24.183230682874054, 1.5796707600148068), (13.902102579766733, 105.96164660793619), (-41.78112251917578, 119.95013554368859), (-39.52661969998466, -172.3209339501041), (58.157764866792405, 126.69963047590261), (87.52682611139446, -60.47350577120804), (-55.76435860128852, -58.57438157850763), (-29.19441152139303, -167.28169895399026), (57.418098692271144, 6.331472956151458), (-47.65871688328195, 78.8042317431362), (19.318395243351247, -149.98403414534752), (19.58316543694842, -111.85631719917251), (72.23281256038683, -45.833076012963375), (29.438131104231047, 49.98125387517453), (10.832970297497454, 119.66161716490893), (-50.03379762881465, 99.80077430465445), (-22.957305583020187, 114.09450353323018), (-50.456244731411985, -108.39698267622572), (48.98847554087422, 174.05187450065932), (52.00973047027017, -149.5300402453409), (-0 ...

# %%
# Get the nearest city using the citipy module.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    
    
      # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | leshukonskoye
# Processing Record 5 of Set 1 | airai
# Processing Record 6 of Set 1 | mitsamiouli
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | buala
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | burica
# City not found. Skipping...
# Processing Record 13 of Set 1 | la ronge
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | quatre cocos
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | zhetysay
# Processing Record 21 of Set 1 | nakambala
# Processing Record 22 of Set 1 | cabedelo
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | itarema
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | abalak
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | salekhard
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | haines junction
# Processing Record 32 of Set 1 | mayo
# Processing Record 33 of Set 1 | vanimo
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | kishtwar
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | mahibadhoo
# Processing Record 40 of Set 1 | naze
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | scarborough
# Processing Record 43 of Set 1 | camabatela
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | taltal
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | touros
# Processing Record 48 of Set 1 | saint-felicien
# Processing Record 49 of Set 1 | whitehorse
# Processing Record 50 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 2 | faanui
# Processing Record 2 of Set 2 | saint-pierre
# Processing Record 3 of Set 2 | lagoa
# Processing Record 4 of Set 2 | torbat-e jam
# Processing Record 5 of Set 2 | methala
# Processing Record 6 of Set 2 | hasaki
# Processing Record 7 of Set 2 | kapit
# Processing Record 8 of Set 2 | evensk
# Processing Record 9 of Set 2 | tessalit
# Processing Record 10 of Set 2 | champasak
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | tommot
# Processing Record 13 of Set 2 | narsaq
# Processing Record 14 of Set 2 | alofi
# Processing Record 15 of Set 2 | vestbygda
# City not found. Skipping...
# Processing Record 16 of Set 2 | cabo san lucas
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | hendijan
# City not found. Skipping...
# Processing Record 19 of Set 2 | taytay
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | mazagao
# Processing Record 23 of Set 2 | kaoma
# Processing Record 24 of Set 2 | toguchin
# Processing Record 25 of Set 2 | sao filipe
# Processing Record 26 of Set 2 | harper
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | san quintin
# Processing Record 30 of Set 2 | vao
# Processing Record 31 of Set 2 | khatanga
# Processing Record 32 of Set 2 | villarrica
# Processing Record 33 of Set 2 | clyde river
# Processing Record 34 of Set 2 | madimba
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | vaitape
# Processing Record 37 of Set 2 | shreveport
# Processing Record 38 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 2 | vila franca do campo
# Processing Record 41 of Set 2 | minsk
# Processing Record 42 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | butaritari
# Processing Record 45 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 2 | bengkulu
# Processing Record 47 of Set 2 | lompoc
# Processing Record 48 of Set 2 | inhambane
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | skjervoy
# Processing Record 1 of Set 3 | kodinsk
# Processing Record 2 of Set 3 | katsuura
# Processing Record 3 of Set 3 | fernie
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | kawalu
# Processing Record 6 of Set 3 | provideniya
# Processing Record 7 of Set 3 | grindavik
# Processing Record 8 of Set 3 | tabou
# Processing Record 9 of Set 3 | montbrison
# Processing Record 10 of Set 3 | falmouth
# Processing Record 11 of Set 3 | bambous virieux
# Processing Record 12 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 13 of Set 3 | dabakala
# Processing Record 14 of Set 3 | xuddur
# Processing Record 15 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 3 | maputo
# Processing Record 17 of Set 3 | coquimbo
# Processing Record 18 of Set 3 | raga
# Processing Record 19 of Set 3 | mar del plata
# Processing Record 20 of Set 3 | cayenne
# Processing Record 21 of Set 3 | fairbanks
# Processing Record 22 of Set 3 | ponta do sol
# Processing Record 23 of Set 3 | dunedin
# Processing Record 24 of Set 3 | sitka
# Processing Record 25 of Set 3 | sorland
# Processing Record 26 of Set 3 | tsiroanomandidy
# Processing Record 27 of Set 3 | kapaa
# Processing Record 28 of Set 3 | klaksvik
# Processing Record 29 of Set 3 | jangaon
# Processing Record 30 of Set 3 | bilma
# Processing Record 31 of Set 3 | kudahuvadhoo
# Processing Record 32 of Set 3 | ostrovnoy
# Processing Record 33 of Set 3 | atuona
# Processing Record 34 of Set 3 | san patricio
# Processing Record 35 of Set 3 | thunder bay
# Processing Record 36 of Set 3 | tilichiki
# Processing Record 37 of Set 3 | savalou
# Processing Record 38 of Set 3 | kruisfontein
# Processing Record 39 of Set 3 | igarape-acu
# City not found. Skipping...
# Processing Record 40 of Set 3 | moncton
# Processing Record 41 of Set 3 | half moon bay
# Processing Record 42 of Set 3 | tampin
# Processing Record 43 of Set 3 | novyy urengoy
# Processing Record 44 of Set 3 | sarkand
# Processing Record 45 of Set 3 | portree
# Processing Record 46 of Set 3 | aitape
# Processing Record 47 of Set 3 | copiapo
# Processing Record 48 of Set 3 | suihua
# Processing Record 49 of Set 3 | mataura
# Processing Record 50 of Set 3 | arcata
# Processing Record 1 of Set 4 | pringsewu
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | kaitangata
# Processing Record 4 of Set 4 | ust-nera
# Processing Record 5 of Set 4 | banda aceh
# Processing Record 6 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 4 | selikhino
# Processing Record 8 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 4 | kidal
# Processing Record 10 of Set 4 | churapcha
# Processing Record 11 of Set 4 | new norfolk
# Processing Record 12 of Set 4 | comodoro rivadavia
# Processing Record 13 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | lagunas
# Processing Record 16 of Set 4 | kahului
# Processing Record 17 of Set 4 | camana
# Processing Record 18 of Set 4 | guerrero negro
# Processing Record 19 of Set 4 | bontang
# Processing Record 20 of Set 4 | qobu
# Processing Record 21 of Set 4 | sinnar
# Processing Record 22 of Set 4 | bandarbeyla
# Processing Record 23 of Set 4 | hervey bay
# Processing Record 24 of Set 4 | hofn
# Processing Record 25 of Set 4 | westport
# Processing Record 26 of Set 4 | saskylakh
# Processing Record 27 of Set 4 | champerico
# Processing Record 28 of Set 4 | ancud
# Processing Record 29 of Set 4 | bakchar
# Processing Record 30 of Set 4 | nago
# Processing Record 31 of Set 4 | maneadero
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | baruun-urt
# Processing Record 34 of Set 4 | shelburne
# Processing Record 35 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 4 | mandalgovi
# Processing Record 37 of Set 4 | hay river
# Processing Record 38 of Set 4 | puerto escondido
# Processing Record 39 of Set 4 | oeiras do para
# Processing Record 40 of Set 4 | tonantins
# Processing Record 41 of Set 4 | itoman
# Processing Record 42 of Set 4 | altonia
# City not found. Skipping...
# Processing Record 43 of Set 4 | jeremie
# Processing Record 44 of Set 4 | okha
# Processing Record 45 of Set 4 | norman wells
# Processing Record 46 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 47 of Set 4 | cape town
# Processing Record 48 of Set 4 | brigantine
# Processing Record 49 of Set 4 | bubaque
# Processing Record 50 of Set 4 | sanica
# Processing Record 1 of Set 5 | jahrom
# City not found. Skipping...
# Processing Record 2 of Set 5 | mityana
# Processing Record 3 of Set 5 | vestmannaeyjar
# Processing Record 4 of Set 5 | victoria
# Processing Record 5 of Set 5 | fortuna
# Processing Record 6 of Set 5 | coahuayana
# Processing Record 7 of Set 5 | yulara
# Processing Record 8 of Set 5 | victor harbor
# Processing Record 9 of Set 5 | yumen
# Processing Record 10 of Set 5 | lavrentiya
# Processing Record 11 of Set 5 | palu
# Processing Record 12 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 5 | port alfred
# Processing Record 14 of Set 5 | durant
# Processing Record 15 of Set 5 | erzin
# Processing Record 16 of Set 5 | medicine hat
# Processing Record 17 of Set 5 | olafsvik
# Processing Record 18 of Set 5 | balkanabat
# Processing Record 19 of Set 5 | ouegoa
# Processing Record 20 of Set 5 | dikson
# Processing Record 21 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 5 | baisha
# Processing Record 23 of Set 5 | katerero
# Processing Record 24 of Set 5 | talcahuano
# Processing Record 25 of Set 5 | grand gaube
# Processing Record 26 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 5 | puerto madryn
# Processing Record 28 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 5 | kirakira
# Processing Record 30 of Set 5 | san cristobal
# Processing Record 31 of Set 5 | husavik
# Processing Record 32 of Set 5 | kamaishi
# Processing Record 33 of Set 5 | iqaluit
# Processing Record 34 of Set 5 | puerto maldonado
# Processing Record 35 of Set 5 | aklavik
# Processing Record 36 of Set 5 | kizlyar
# Processing Record 37 of Set 5 | saint george
# Processing Record 38 of Set 5 | nome
# Processing Record 39 of Set 5 | bethel
# Processing Record 40 of Set 5 | odweyne
# Processing Record 41 of Set 5 | east london
# Processing Record 42 of Set 5 | paamiut
# Processing Record 43 of Set 5 | ayan
# Processing Record 44 of Set 5 | silver city
# Processing Record 45 of Set 5 | los llanos de aridane
# Processing Record 46 of Set 5 | jamestown
# Processing Record 47 of Set 5 | asau
# Processing Record 48 of Set 5 | yar-sale
# Processing Record 49 of Set 5 | tiznit
# Processing Record 50 of Set 5 | high level
# Processing Record 1 of Set 6 | hithadhoo
# Processing Record 2 of Set 6 | batsfjord
# Processing Record 3 of Set 6 | arlit
# Processing Record 4 of Set 6 | socorro
# Processing Record 5 of Set 6 | guarapari
# Processing Record 6 of Set 6 | parsons
# Processing Record 7 of Set 6 | avdon
# Processing Record 8 of Set 6 | kracheh
# City not found. Skipping...
# Processing Record 9 of Set 6 | riyadh
# Processing Record 10 of Set 6 | lamidan
# City not found. Skipping...
# Processing Record 11 of Set 6 | indramayu
# Processing Record 12 of Set 6 | viedma
# Processing Record 13 of Set 6 | inuvik
# Processing Record 14 of Set 6 | sidi bu zayd
# City not found. Skipping...
# Processing Record 15 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 16 of Set 6 | olinda
# Processing Record 17 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 6 | severo-kurilsk
# Processing Record 19 of Set 6 | bay roberts
# Processing Record 20 of Set 6 | ndjole
# Processing Record 21 of Set 6 | bitung
# Processing Record 22 of Set 6 | poum
# Processing Record 23 of Set 6 | ahuimanu
# Processing Record 24 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 6 | varhaug
# Processing Record 26 of Set 6 | waitati
# Processing Record 27 of Set 6 | chokurdakh
# Processing Record 28 of Set 6 | kavieng
# Processing Record 29 of Set 6 | kabakovo
# Processing Record 30 of Set 6 | lincoln
# Processing Record 31 of Set 6 | exu
# Processing Record 32 of Set 6 | tura
# Processing Record 33 of Set 6 | umtata
# Processing Record 34 of Set 6 | chuy
# Processing Record 35 of Set 6 | salamanca
# Processing Record 36 of Set 6 | valleyview
# Processing Record 37 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 6 | lebu
# Processing Record 39 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 6 | deputatskiy
# Processing Record 42 of Set 6 | pierre
# Processing Record 43 of Set 6 | lorengau
# Processing Record 44 of Set 6 | hamilton
# Processing Record 45 of Set 6 | ossora
# Processing Record 46 of Set 6 | broome
# Processing Record 47 of Set 6 | ust-kan
# Processing Record 48 of Set 6 | forbes
# Processing Record 49 of Set 6 | dubbo
# Processing Record 50 of Set 6 | biggar
# Processing Record 1 of Set 7 | nenton
# Processing Record 2 of Set 7 | innisfail
# Processing Record 3 of Set 7 | manyana
# Processing Record 4 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 7 | souillac
# Processing Record 6 of Set 7 | berdigestyakh
# Processing Record 7 of Set 7 | byron bay
# Processing Record 8 of Set 7 | richards bay
# Processing Record 9 of Set 7 | maua
# Processing Record 10 of Set 7 | mount isa
# Processing Record 11 of Set 7 | robertsport
# Processing Record 12 of Set 7 | bucerias
# Processing Record 13 of Set 7 | honiara
# Processing Record 14 of Set 7 | te anau
# Processing Record 15 of Set 7 | laguna
# Processing Record 16 of Set 7 | pestretsy
# Processing Record 17 of Set 7 | vostok
# Processing Record 18 of Set 7 | pisco
# Processing Record 19 of Set 7 | moree
# Processing Record 20 of Set 7 | alice springs
# Processing Record 21 of Set 7 | eyl
# Processing Record 22 of Set 7 | santa maria
# Processing Record 23 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 7 | calvinia
# Processing Record 25 of Set 7 | alta floresta
# Processing Record 26 of Set 7 | nanortalik
# Processing Record 27 of Set 7 | potsdam
# Processing Record 28 of Set 7 | parati
# Processing Record 29 of Set 7 | koslan
# Processing Record 30 of Set 7 | vila velha
# Processing Record 31 of Set 7 | road town
# Processing Record 32 of Set 7 | lakheri
# Processing Record 33 of Set 7 | luanda
# Processing Record 34 of Set 7 | ponta delgada
# Processing Record 35 of Set 7 | pacific grove
# Processing Record 36 of Set 7 | borogontsy
# Processing Record 37 of Set 7 | jinchang
# Processing Record 38 of Set 7 | esperance
# Processing Record 39 of Set 7 | mackenzie
# Processing Record 40 of Set 7 | kirillov
# Processing Record 41 of Set 7 | coos bay
# Processing Record 42 of Set 7 | zlatoustovsk
# City not found. Skipping...
# Processing Record 43 of Set 7 | trairi
# Processing Record 44 of Set 7 | dohar
# Processing Record 45 of Set 7 | dicabisagan
# Processing Record 46 of Set 7 | launceston
# Processing Record 47 of Set 7 | codrington
# Processing Record 48 of Set 7 | pevek
# Processing Record 49 of Set 7 | anadyr
# Processing Record 50 of Set 7 | krasnoarmeysk
# Processing Record 1 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 8 | helena
# Processing Record 3 of Set 8 | pitsunda
# Processing Record 4 of Set 8 | havoysund
# Processing Record 5 of Set 8 | ranong
# Processing Record 6 of Set 8 | bend
# Processing Record 7 of Set 8 | pagman
# City not found. Skipping...
# Processing Record 8 of Set 8 | braganca
# Processing Record 9 of Set 8 | sur
# Processing Record 10 of Set 8 | dhidhdhoo
# Processing Record 11 of Set 8 | sumbe
# Processing Record 12 of Set 8 | leningradskiy
# Processing Record 13 of Set 8 | nortelandia
# Processing Record 14 of Set 8 | cruzilia
# Processing Record 15 of Set 8 | ambon
# Processing Record 16 of Set 8 | la reforma
# Processing Record 17 of Set 8 | kalakamati
# Processing Record 18 of Set 8 | hovd
# Processing Record 19 of Set 8 | talnakh
# Processing Record 20 of Set 8 | praia da vitoria
# Processing Record 21 of Set 8 | marina
# Processing Record 22 of Set 8 | baykit
# Processing Record 23 of Set 8 | xining
# Processing Record 24 of Set 8 | fairview
# Processing Record 25 of Set 8 | nuevo progreso
# Processing Record 26 of Set 8 | kargasok
# Processing Record 27 of Set 8 | georgetown
# Processing Record 28 of Set 8 | la asuncion
# Processing Record 29 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 30 of Set 8 | zaranj
# Processing Record 31 of Set 8 | inirida
# Processing Record 32 of Set 8 | chapais
# Processing Record 33 of Set 8 | glyadyanskoye
# Processing Record 34 of Set 8 | sao francisco de assis
# Processing Record 35 of Set 8 | arman
# Processing Record 36 of Set 8 | ileza
# Processing Record 37 of Set 8 | manzanillo
# Processing Record 38 of Set 8 | bayir
# Processing Record 39 of Set 8 | goderich
# Processing Record 40 of Set 8 | alugan
# Processing Record 41 of Set 8 | margate
# Processing Record 42 of Set 8 | qaqortoq
# Processing Record 43 of Set 8 | smithers
# Processing Record 44 of Set 8 | srednekolymsk
# Processing Record 45 of Set 8 | port hardy
# Processing Record 46 of Set 8 | saint-junien
# Processing Record 47 of Set 8 | ucluelet
# Processing Record 48 of Set 8 | namibe
# Processing Record 49 of Set 8 | carsamba
# Processing Record 50 of Set 8 | adelaide
# Processing Record 1 of Set 9 | saldanha
# Processing Record 2 of Set 9 | porto murtinho
# Processing Record 3 of Set 9 | ust-ishim
# Processing Record 4 of Set 9 | yaan
# Processing Record 5 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 9 | aswan
# Processing Record 7 of Set 9 | nenjiang
# Processing Record 8 of Set 9 | nanakuli
# Processing Record 9 of Set 9 | sola
# Processing Record 10 of Set 9 | kaitong
# Processing Record 11 of Set 9 | orkney
# Processing Record 12 of Set 9 | buin
# Processing Record 13 of Set 9 | longyearbyen
# Processing Record 14 of Set 9 | denham springs
# Processing Record 15 of Set 9 | kemijarvi
# Processing Record 16 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 17 of Set 9 | waipawa
# Processing Record 18 of Set 9 | sao joao da barra
# Processing Record 19 of Set 9 | blagoyevo
# Processing Record 20 of Set 9 | lusaka
# Processing Record 21 of Set 9 | biltine
# Processing Record 22 of Set 9 | tiksi
# Processing Record 23 of Set 9 | tuatapere
# Processing Record 24 of Set 9 | tiarei
# Processing Record 25 of Set 9 | mount gambier
# Processing Record 26 of Set 9 | marystown
# Processing Record 27 of Set 9 | novoagansk
# Processing Record 28 of Set 9 | chiredzi
# Processing Record 29 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 9 | honningsvag
# Processing Record 31 of Set 9 | guantanamo
# Processing Record 32 of Set 9 | mehamn
# Processing Record 33 of Set 9 | safakulevo
# Processing Record 34 of Set 9 | the pas
# Processing Record 35 of Set 9 | jibuti
# Processing Record 36 of Set 9 | lovington
# Processing Record 37 of Set 9 | komsomolskiy
# Processing Record 38 of Set 9 | vardo
# Processing Record 39 of Set 9 | ternate
# Processing Record 40 of Set 9 | saquena
# Processing Record 41 of Set 9 | houma
# Processing Record 42 of Set 9 | buchanan
# Processing Record 43 of Set 9 | dalianwan
# Processing Record 44 of Set 9 | cherskiy
# Processing Record 45 of Set 9 | santa isabel do rio negro
# Processing Record 46 of Set 9 | havre-saint-pierre
# Processing Record 47 of Set 9 | aguimes
# Processing Record 48 of Set 9 | nouakchott
# Processing Record 49 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 9 | belyy yar
# Processing Record 1 of Set 10 | caravelas
# Processing Record 2 of Set 10 | balabac
# Processing Record 3 of Set 10 | haimen
# Processing Record 4 of Set 10 | ust-kuyga
# Processing Record 5 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 10 | kieta
# Processing Record 7 of Set 10 | zhelyabovka
# Processing Record 8 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 10 | acarau
# Processing Record 10 of Set 10 | cabo rojo
# Processing Record 11 of Set 10 | avera
# Processing Record 12 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 10 | kapoeta
# Processing Record 14 of Set 10 | hambantota
# Processing Record 15 of Set 10 | coihaique
# Processing Record 16 of Set 10 | uruzgan
# Processing Record 17 of Set 10 | axim
# Processing Record 18 of Set 10 | male
# Processing Record 19 of Set 10 | zeya
# Processing Record 20 of Set 10 | khakhea
# Processing Record 21 of Set 10 | bathsheba
# Processing Record 22 of Set 10 | nador
# Processing Record 23 of Set 10 | torrevieja
# Processing Record 24 of Set 10 | san jose
# Processing Record 25 of Set 10 | lubao
# Processing Record 26 of Set 10 | murdochville
# Processing Record 27 of Set 10 | buncrana
# Processing Record 28 of Set 10 | pomabamba
# Processing Record 29 of Set 10 | zyryanovsk
# Processing Record 30 of Set 10 | mashhad
# Processing Record 31 of Set 10 | umm lajj
# Processing Record 32 of Set 10 | stepnyak
# Processing Record 33 of Set 10 | ambovombe
# Processing Record 34 of Set 10 | banyo
# Processing Record 35 of Set 10 | jaca
# Processing Record 36 of Set 10 | zelenoborsk
# Processing Record 37 of Set 10 | linchuan
# City not found. Skipping...
# Processing Record 38 of Set 10 | langenburg
# Processing Record 39 of Set 10 | samdrup jongkhar
# Processing Record 40 of Set 10 | walvis bay
# Processing Record 41 of Set 10 | inongo
# Processing Record 42 of Set 10 | turhal
# Processing Record 43 of Set 10 | acari
# Processing Record 44 of Set 10 | kochki
# Processing Record 45 of Set 10 | tabas
# Processing Record 46 of Set 10 | la primavera
# Processing Record 47 of Set 10 | matagalpa
# Processing Record 48 of Set 10 | samarai
# Processing Record 49 of Set 10 | chakrata
# Processing Record 50 of Set 10 | bara
# Processing Record 1 of Set 11 | visby
# Processing Record 2 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 11 | gilgit
# Processing Record 4 of Set 11 | boguchany
# Processing Record 5 of Set 11 | humaita
# Processing Record 6 of Set 11 | catamarca
# Processing Record 7 of Set 11 | luderitz
# Processing Record 8 of Set 11 | sobolevo
# Processing Record 9 of Set 11 | kysyl-syr
# Processing Record 10 of Set 11 | camaqua
# Processing Record 11 of Set 11 | west bay
# Processing Record 12 of Set 11 | kenora
# Processing Record 13 of Set 11 | basqal
# Processing Record 14 of Set 11 | taiyuan
# Processing Record 15 of Set 11 | miraflores
# Processing Record 16 of Set 11 | bria
# Processing Record 17 of Set 11 | chopda
# Processing Record 18 of Set 11 | necochea
# Processing Record 19 of Set 11 | sinazongwe
# Processing Record 20 of Set 11 | chulman
# Processing Record 21 of Set 11 | tavricheskoye
# Processing Record 22 of Set 11 | xiongshi
# City not found. Skipping...
# Processing Record 23 of Set 11 | noumea
# Processing Record 24 of Set 11 | shache
# Processing Record 25 of Set 11 | san angelo
# Processing Record 26 of Set 11 | alanya
# Processing Record 27 of Set 11 | karratha
# Processing Record 28 of Set 11 | dauphin
# Processing Record 29 of Set 11 | porto santo
# Processing Record 30 of Set 11 | auki
# Processing Record 31 of Set 11 | ugoofaaru
# Processing Record 32 of Set 11 | nantucket
# Processing Record 33 of Set 11 | praya
# Processing Record 34 of Set 11 | muscat
# Processing Record 35 of Set 11 | oxbow
# Processing Record 36 of Set 11 | romblon
# Processing Record 37 of Set 11 | maningrida
# Processing Record 38 of Set 11 | scalea
# Processing Record 39 of Set 11 | miandrivazo
# Processing Record 40 of Set 11 | saint-prosper
# Processing Record 41 of Set 11 | saint-francois
# Processing Record 42 of Set 11 | jackson
# Processing Record 43 of Set 11 | teknaf
# Processing Record 44 of Set 11 | northam
# Processing Record 45 of Set 11 | san pedro
# Processing Record 46 of Set 11 | charters towers
# Processing Record 47 of Set 11 | eyrarbakki
# Processing Record 48 of Set 11 | lanivtsi
# Processing Record 49 of Set 11 | naryan-mar
# Processing Record 50 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 12 | mendahara
# City not found. Skipping...
# Processing Record 2 of Set 12 | saint-joseph
# Processing Record 3 of Set 12 | toamasina
# Processing Record 4 of Set 12 | la orilla
# Processing Record 5 of Set 12 | sibu
# Processing Record 6 of Set 12 | zhezkazgan
# Processing Record 7 of Set 12 | soe
# Processing Record 8 of Set 12 | asyut
# Processing Record 9 of Set 12 | brazzaville
# Processing Record 10 of Set 12 | mombetsu
# Processing Record 11 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 12 | camacha
# Processing Record 13 of Set 12 | petukhovo
# Processing Record 14 of Set 12 | arbuzynka
# Processing Record 15 of Set 12 | kastamonu
# Processing Record 16 of Set 12 | general roca
# Processing Record 17 of Set 12 | along
# Processing Record 18 of Set 12 | maceio
# Processing Record 19 of Set 12 | salinas
# Processing Record 20 of Set 12 | kamensk-uralskiy
# Processing Record 21 of Set 12 | araguaina
# Processing Record 22 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 12 | nongan
# Processing Record 24 of Set 12 | pyay
# Processing Record 25 of Set 12 | serenje
# Processing Record 26 of Set 12 | broken hill
# Processing Record 27 of Set 12 | green river
# Processing Record 28 of Set 12 | kalmunai
# Processing Record 29 of Set 12 | rawson
# Processing Record 30 of Set 12 | iberia
# Processing Record 31 of Set 12 | agadez
# Processing Record 32 of Set 12 | salalah
# Processing Record 33 of Set 12 | sadove
# Processing Record 34 of Set 12 | santa vitoria do palmar
# Processing Record 35 of Set 12 | clyde
# Processing Record 36 of Set 12 | yenagoa
# Processing Record 37 of Set 12 | joshimath
# Processing Record 38 of Set 12 | isiro
# Processing Record 39 of Set 12 | lasa
# Processing Record 40 of Set 12 | shingu
# Processing Record 41 of Set 12 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 42 of Set 12 | bandarban
# Processing Record 43 of Set 12 | neuquen
# Processing Record 44 of Set 12 | killam
# Processing Record 45 of Set 12 | mae ramat
# Processing Record 46 of Set 12 | werda
# Processing Record 47 of Set 12 | brownwood
# Processing Record 48 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 49 of Set 12 | huejuquilla el alto
# Processing Record 50 of Set 12 | coffs harbour
# Processing Record 1 of Set 13 | alyangula
# Processing Record 2 of Set 13 | saint-augustin
# Processing Record 3 of Set 13 | taguatinga
# Processing Record 4 of Set 13 | were ilu
# Processing Record 5 of Set 13 | izacic
# Processing Record 6 of Set 13 | gazli
# Processing Record 7 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 13 | atar
# Processing Record 9 of Set 13 | channel-port aux basques
# Processing Record 10 of Set 13 | krasnyy chikoy
# Processing Record 11 of Set 13 | haveli
# Processing Record 12 of Set 13 | new richmond
# Processing Record 13 of Set 13 | hauterive
# Processing Record 14 of Set 13 | prado
# Processing Record 15 of Set 13 | brookhaven
# Processing Record 16 of Set 13 | vila
# Processing Record 17 of Set 13 | muisne
# Processing Record 18 of Set 13 | the valley
# Processing Record 19 of Set 13 | fare
# Processing Record 20 of Set 13 | ondangwa
# Processing Record 21 of Set 13 | novogurovskiy
# Processing Record 22 of Set 13 | egvekinot
# Processing Record 23 of Set 13 | ibotirama
# Processing Record 24 of Set 13 | poopo
# Processing Record 25 of Set 13 | sambava
# Processing Record 26 of Set 13 | vrontados
# Processing Record 27 of Set 13 | strezhevoy
# Processing Record 28 of Set 13 | segezha
# Processing Record 29 of Set 13 | constantine
# Processing Record 30 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 31 of Set 13 | chicama
# Processing Record 32 of Set 13 | show low
# Processing Record 33 of Set 13 | meadow lake
# Processing Record 34 of Set 13 | red wing
# Processing Record 35 of Set 13 | kuah
# Processing Record 36 of Set 13 | polyarnyy
# Processing Record 37 of Set 13 | elliot lake
# Processing Record 38 of Set 13 | ponnani
# Processing Record 39 of Set 13 | sechura
# Processing Record 40 of Set 13 | ekhabi
# Processing Record 41 of Set 13 | lac du bonnet
# Processing Record 42 of Set 13 | pangnirtung
# Processing Record 43 of Set 13 | chara
# Processing Record 44 of Set 13 | bunia
# Processing Record 45 of Set 13 | kavaratti
# Processing Record 46 of Set 13 | bocaiuva
# Processing Record 47 of Set 13 | yerbogachen
# Processing Record 48 of Set 13 | tigzirt
# Processing Record 49 of Set 13 | tlacotepec
# Processing Record 50 of Set 13 | krasnoye
# Processing Record 1 of Set 14 | port blair
# Processing Record 2 of Set 14 | tautira
# Processing Record 3 of Set 14 | valparaiso
# Processing Record 4 of Set 14 | celestun
# Processing Record 5 of Set 14 | aborlan
# Processing Record 6 of Set 14 | koundara
# Processing Record 7 of Set 14 | cockburn town
# Processing Record 8 of Set 14 | akureyri
# Processing Record 9 of Set 14 | mercedes
# Processing Record 10 of Set 14 | luyang
# Processing Record 11 of Set 14 | santo tomas
# Processing Record 12 of Set 14 | macklin
# Processing Record 13 of Set 14 | kuldiga
# Processing Record 14 of Set 14 | gornyak
# Processing Record 15 of Set 14 | issoire
# Processing Record 16 of Set 14 | makakilo city
# Processing Record 17 of Set 14 | luwuk
# Processing Record 18 of Set 14 | lafia
# Processing Record 19 of Set 14 | tazovskiy
# Processing Record 20 of Set 14 | burns lake
# Processing Record 21 of Set 14 | san jeronimo
# Processing Record 22 of Set 14 | masingbi
# Processing Record 23 of Set 14 | presidencia roque saenz pena
# Processing Record 24 of Set 14 | ballina
# Processing Record 25 of Set 14 | qui nhon
# Processing Record 26 of Set 14 | store heddinge
# Processing Record 27 of Set 14 | guadalupe victoria
# Processing Record 28 of Set 14 | karatau
# Processing Record 29 of Set 14 | calama
# Processing Record 30 of Set 14 | domna
# Processing Record 31 of Set 14 | awjilah
# Processing Record 32 of Set 14 | derzhavinsk
# Processing Record 33 of Set 14 | ajdabiya
# Processing Record 34 of Set 14 | tabuk
# Processing Record 35 of Set 14 | tomatlan
# Processing Record 36 of Set 14 | adrar
# Processing Record 37 of Set 14 | sungairaya
# Processing Record 38 of Set 14 | mariinsk
# Processing Record 39 of Set 14 | krasnokamensk
# Processing Record 40 of Set 14 | port lincoln
# Processing Record 41 of Set 14 | soyo
# Processing Record 42 of Set 14 | santa rosa
# Processing Record 43 of Set 14 | lewiston
# Processing Record 44 of Set 14 | ushumun
# Processing Record 45 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 46 of Set 14 | beringovskiy
# Processing Record 47 of Set 14 | raudeberg
# Processing Record 48 of Set 14 | batagay-alyta
# Processing Record 49 of Set 14 | ketchikan
# Processing Record 50 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 15 | boyolangu
# Processing Record 2 of Set 15 | ahipara
# Processing Record 3 of Set 15 | dourbali
# Processing Record 4 of Set 15 | brainerd
# Processing Record 5 of Set 15 | qandala
# Processing Record 6 of Set 15 | wajima
# Processing Record 7 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 15 | krasnomayskiy
# Processing Record 9 of Set 15 | korem
# Processing Record 10 of Set 15 | tezu
# Processing Record 11 of Set 15 | mayor pablo lagerenza
# Processing Record 12 of Set 15 | kargil
# Processing Record 13 of Set 15 | yeniseysk
# Processing Record 14 of Set 15 | sungaipenuh
# Processing Record 15 of Set 15 | batagay
# Processing Record 16 of Set 15 | terrak
# Processing Record 17 of Set 15 | okato
# Processing Record 18 of Set 15 | manacor
# Processing Record 19 of Set 15 | surata
# City not found. Skipping...
# Processing Record 20 of Set 15 | huanren
# Processing Record 21 of Set 15 | senneterre
# Processing Record 22 of Set 15 | serebriya
# Processing Record 23 of Set 15 | gornyy
# Processing Record 24 of Set 15 | juba
# Processing Record 25 of Set 15 | wajid
# Processing Record 26 of Set 15 | kropotkin
# Processing Record 27 of Set 15 | jardim
# Processing Record 28 of Set 15 | tambacounda
# Processing Record 29 of Set 15 | venado tuerto
# Processing Record 30 of Set 15 | shimoda
# Processing Record 31 of Set 15 | hanna
# Processing Record 32 of Set 15 | llangefni
# Processing Record 33 of Set 15 | jalu
# Processing Record 34 of Set 15 | belozerskoye
# Processing Record 35 of Set 15 | santa lucia
# Processing Record 36 of Set 15 | merauke
# Processing Record 37 of Set 15 | paidha
# Processing Record 38 of Set 15 | rio verde de mato grosso
# Processing Record 39 of Set 15 | cusuna
# Processing Record 40 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 15 | wahiawa
# Processing Record 42 of Set 15 | pietarsaari
# Processing Record 43 of Set 15 | rio gallegos
# Processing Record 44 of Set 15 | faya
# Processing Record 45 of Set 15 | nouadhibou
# Processing Record 46 of Set 15 | constitucion
# Processing Record 47 of Set 15 | shellbrook
# Processing Record 48 of Set 15 | malanje
# Processing Record 49 of Set 15 | nizhniy kuranakh
# Processing Record 50 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 16 | kungurtug
# Processing Record 2 of Set 16 | ulagan
# Processing Record 3 of Set 16 | jumla
# Processing Record 4 of Set 16 | mogochin
# City not found. Skipping...
# Processing Record 5 of Set 16 | shunyi
# Processing Record 6 of Set 16 | diapaga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
# Add the data to a new DataFrame.


city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hilo      US  19.7297 -155.0900     82.27        82         100
# 1   Punta Arenas      CL -53.1500  -70.9167     48.31        43           0
# 2         Barrow      US  71.2906 -156.7887     37.42        93         100
# 3  Leshukonskoye      RU  64.8989   45.7622     44.87        98          71
# 4          Airai      TL  -8.9266  125.4092     58.42        49          97
# 5    Mitsamiouli      KM -11.3847   43.2844     75.72        81           5
# 6         Avarua      CK -21.2078 -159.7750     80.65        74           7
# 7          Buala      SB  -8.1450  159.5921     81.12        84          96
# 8     Nikolskoye      RU  59.7035   30.7861     49.89        87         100
# 9         Albany      US  42.6001  -73.9662     78.58        81          94
#
#    Wind Speed Current Description
# 0        5.75     overcast clouds
# 1        8.05           clear sky
# 2       23.02     overcast clouds
# 3        5.66       broken clouds
# 4        2.77     overcast clouds
# 5        9.89           clear sky
# 6        4.61           clear sky
# 7       19.17       moderate rain
# 8        1.92     overcast clouds
# 9        9.19     overcast clouds

# %%
import csv

# %%
# Export the DataFrame as WeatherPy_Database.csv into the Weather_Database folder (5 pt)

# create output file
output_data_file = "city_data.csv"

# Export city_data to csv
city_data_df.to_csv(output_data_file, index_label = "WeatherPy_Database")
