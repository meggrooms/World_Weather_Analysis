# %%
# Create a new set of 2,000 random latitudes and longitudes.

# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# One can only unzip a zipped tuple once before it is removed from the computer's memory. 
# Make sure to unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Starting URL for Weather Map API Call.
# url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(-12.073742355238593, 31.504698041613295), (-16.28011795556877, -176.87930147040214), (45.8260852464966, -113.69439243448373), (-42.879455623339254, 159.94890238243568), (89.05117487548083, -109.25934765227427), (48.258745714591555, 82.84565046989417), (-33.66167594789883, -10.955907399329249), (21.926255489556624, -98.91630853450228), (-13.700090601279328, 7.493382633025192), (86.70755476519841, 13.266330437369845), (49.637236162569536, -115.01945136630073), (-66.51443577941455, 80.61768755126923), (65.34080574146918, 154.92688117263333), (-59.12574995324849, -0.2948221797522592), (-81.7156607858423, -140.90158527656115), (46.98381999670937, 142.5639614244178), (89.20173538712484, 76.37477073128258), (87.31734203387143, -2.144294869540431), (-7.625431362585559, -49.343805554994304), (-0.7384473805672371, -148.92542708072693), (39.257356814659715, -143.94591292664657), (-63.97751148502196, 174.08179617157123), (68.64811375311254, -68.37321858455078), (45.1718067342359, -178.69527332940368), (-14.825089729488482, 8.243479638273982), (26.41448833626481, 19.166395646465418), (-34.64031903931087, -10.851445096614867), (53.41753033434537, 50.8241002204189), (77.49863197013994, 35.88370113750025), (25.662789284588257, 84.66908851901104), (-56.01972447668101, -39.6703864612756), (86.57933591652022, 82.73711010477518), (20.02072634727081, 93.54746373018565), (16.77671248950169, 70.59411979179862), (9.357569572819543, 29.432034965087553), (-37.100577187126575, 42.089299031508546), (-59.745231967418846, 73.93930939552095), (-79.23603269800056, 144.8262605371619), (-20.54449577881651, -154.04180474203716), (23.394533953079787, 42.18367917861224), (-43.89767727950637, 144.73687756038424), (77.98854121293732, 61.744580556596986), (1.6239343416672511, 14.711482203305309), (69.36555215212786, -102.09923558225707), (-80.38803058712669, 157.4072175070255), (75.37301210657324, 67.15077120164943), (-42.40629615741776, 80.22701173902834), (26.26412852289957, 127.6423540648941), (34.03276254957136, -4.98334389362401), (78.78381634879685, -169.0479192517849), (45.41962658078947, -84.1804167915994), (-41.87606332064638, 3.314719001598519), (39.035002472653616, -62.89405392242665), (35.82703582892091, 85.86085347836422), (-41.69042053439908, -61.56488363457319), (-12.508717580867255, 143.78713704258075), (-54.3615507620318, -70.02415100968187), (82.81882801745436, 55.682844435388404), (-43.09478202292626, -127.3244384912292), (-55.23269903187795, 52.92164071025718), (85.09866035271887, -33.95202265344176), (-15.854198455499358, 134.30402756102103), (88.25838868023769, 52.36084311274459), (57.43114745122455, 19.21050037525697), (18.51833231197179, -31.074269115122434), (-32.64304359266102, -14.638614014306086), (12.127471752915369, 114.16697841132395), (39.01547507867019, 90.05611659070775), (-3.903688451768744, 63.75880091667824), (-85.36290087619614, -39.40175698869709), (-37.684064775663586, -31.532531756711677), (1.3081092246434025, -3.549061162608041), (5.1074458710656785, 76.27802019154637), (82.16627832846436, -10.429011179664968), (-56.827973212872195, 38.99438709090319), (-82.08490841373052, -49.10922059008905), (-15.4667371405056, -104.52147927419618), (59.92673805399838, -152.8260328722344), (-84.67070978272103, -129.74778666010468), (-9.18940455451947, 26.07802999405547), (-67.02310867826678, 134.75843753514368), (-40.01898131895187, -124.41727753023936), (56.95874969924719, 149.8745111784619), (39.05261898501354, 71.48230800564338), (-23.557318704894627, -155.66487273416962), (-10.591029798494077, -91.0745395049167), (84.80301724905345, -63.34396508263691), (72.57775535844328, -85.56295102640989), (-55.48281497040512, -52.31383641009322), (-64.87347548271165, 7.154752651646788), (24.55001767400813, -177.24410130744832), (2.639971000129762, -47.72790350271305), (26.012134996980038, 17.518310830858297), (72.5442160515608, 47.63776157976565), (-28.642414441070734, -139.1741999269309), (-42.51303805069063, -57.07636267448291), (-13.379111550 ...

# %%
# Get the nearest city using the citipy module.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    
    
      # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mpika
# Processing Record 2 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 1 | hamilton
# Processing Record 4 of Set 1 | te anau
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | kurchum
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | ciudad valles
# Processing Record 9 of Set 1 | namibe
# Processing Record 10 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 1 | fernie
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | srednekolymsk
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | troitskoye
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | conceicao do araguaia
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | sitka
# Processing Record 21 of Set 1 | kaitangata
# Processing Record 22 of Set 1 | clyde river
# Processing Record 23 of Set 1 | provideniya
# Processing Record 24 of Set 1 | awjilah
# Processing Record 25 of Set 1 | komsomolskiy
# Processing Record 26 of Set 1 | vardo
# Processing Record 27 of Set 1 | ara
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | akyab
# Processing Record 30 of Set 1 | guhagar
# Processing Record 31 of Set 1 | bentiu
# Processing Record 32 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | avera
# Processing Record 36 of Set 1 | mecca
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | sembe
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | tomigusuku
# Processing Record 43 of Set 1 | fez
# Processing Record 44 of Set 1 | lavrentiya
# Processing Record 45 of Set 1 | alpena
# Processing Record 46 of Set 1 | shelburne
# Processing Record 47 of Set 1 | korla
# Processing Record 48 of Set 1 | viedma
# Processing Record 49 of Set 1 | daru
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 2 | visby
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | ransang
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | axim
# Processing Record 12 of Set 2 | male
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | homer
# Processing Record 16 of Set 2 | bukama
# Processing Record 17 of Set 2 | arman
# Processing Record 18 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 19 of Set 2 | san cristobal
# Processing Record 20 of Set 2 | narsaq
# Processing Record 21 of Set 2 | qaanaaq
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | amapa
# Processing Record 25 of Set 2 | sabha
# Processing Record 26 of Set 2 | necochea
# Processing Record 27 of Set 2 | harper
# Processing Record 28 of Set 2 | saint-michel-des-saints
# Processing Record 29 of Set 2 | kalmunai
# Processing Record 30 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | san patricio
# Processing Record 35 of Set 2 | kawalu
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | bengkulu
# Processing Record 38 of Set 2 | hay river
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | faya
# Processing Record 41 of Set 2 | yulara
# Processing Record 42 of Set 2 | yanchukan
# City not found. Skipping...
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | pevek
# Processing Record 46 of Set 2 | lagoa
# Processing Record 47 of Set 2 | grindavik
# Processing Record 48 of Set 2 | nikolskoye
# Processing Record 49 of Set 2 | coruripe
# Processing Record 50 of Set 2 | botwood
# Processing Record 1 of Set 3 | fortuna
# Processing Record 2 of Set 3 | pangnirtung
# Processing Record 3 of Set 3 | hatillo
# Processing Record 4 of Set 3 | chokurdakh
# Processing Record 5 of Set 3 | carutapera
# Processing Record 6 of Set 3 | coahuayana
# Processing Record 7 of Set 3 | elk grove
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | hofn
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | mataura
# Processing Record 12 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 3 | punta alta
# Processing Record 14 of Set 3 | shingu
# Processing Record 15 of Set 3 | mezhdurechensk
# Processing Record 16 of Set 3 | hachinohe
# Processing Record 17 of Set 3 | port macquarie
# Processing Record 18 of Set 3 | palmer
# Processing Record 19 of Set 3 | longyearbyen
# Processing Record 20 of Set 3 | dunedin
# Processing Record 21 of Set 3 | bambous virieux
# Processing Record 22 of Set 3 | suntar
# Processing Record 23 of Set 3 | kavieng
# Processing Record 24 of Set 3 | yinchuan
# Processing Record 25 of Set 3 | palana
# Processing Record 26 of Set 3 | vaini
# Processing Record 27 of Set 3 | severo-kurilsk
# Processing Record 28 of Set 3 | bombay
# Processing Record 29 of Set 3 | sao filipe
# Processing Record 30 of Set 3 | rocha
# Processing Record 31 of Set 3 | baraya
# Processing Record 32 of Set 3 | druzhba
# Processing Record 33 of Set 3 | syracuse
# Processing Record 34 of Set 3 | zyryanka
# Processing Record 35 of Set 3 | iqaluit
# Processing Record 36 of Set 3 | guerrero negro
# Processing Record 37 of Set 3 | lompoc
# Processing Record 38 of Set 3 | bethel
# Processing Record 39 of Set 3 | portalegre
# Processing Record 40 of Set 3 | butaritari
# Processing Record 41 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 3 | antalaha
# Processing Record 43 of Set 3 | alibag
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | upernavik
# Processing Record 46 of Set 3 | laguna
# Processing Record 47 of Set 3 | kununurra
# Processing Record 48 of Set 3 | ozernovskiy
# Processing Record 49 of Set 3 | broken hill
# Processing Record 50 of Set 3 | coquimbo
# Processing Record 1 of Set 4 | pontianak
# Processing Record 2 of Set 4 | belaya gora
# Processing Record 3 of Set 4 | verkhnetulomskiy
# Processing Record 4 of Set 4 | chuy
# Processing Record 5 of Set 4 | vostok
# Processing Record 6 of Set 4 | amargosa
# Processing Record 7 of Set 4 | salalah
# Processing Record 8 of Set 4 | port lincoln
# Processing Record 9 of Set 4 | palaikastron
# Processing Record 10 of Set 4 | katsuura
# Processing Record 11 of Set 4 | uyemskiy
# Processing Record 12 of Set 4 | tieling
# Processing Record 13 of Set 4 | high level
# Processing Record 14 of Set 4 | samana
# Processing Record 15 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 4 | bredasdorp
# Processing Record 19 of Set 4 | manokwari
# Processing Record 20 of Set 4 | jamundi
# Processing Record 21 of Set 4 | guane
# Processing Record 22 of Set 4 | leningradskiy
# Processing Record 23 of Set 4 | khatanga
# Processing Record 24 of Set 4 | bathsheba
# Processing Record 25 of Set 4 | kodiak
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 4 | novhorodka
# Processing Record 29 of Set 4 | byron bay
# Processing Record 30 of Set 4 | mosquera
# Processing Record 31 of Set 4 | palu
# Processing Record 32 of Set 4 | pimentel
# Processing Record 33 of Set 4 | jining
# Processing Record 34 of Set 4 | thompson
# Processing Record 35 of Set 4 | dalbandin
# Processing Record 36 of Set 4 | de-kastri
# Processing Record 37 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 4 | bembereke
# Processing Record 39 of Set 4 | hammerfest
# Processing Record 40 of Set 4 | hithadhoo
# Processing Record 41 of Set 4 | norman wells
# Processing Record 42 of Set 4 | sao joao da barra
# Processing Record 43 of Set 4 | zhangye
# Processing Record 44 of Set 4 | kabelvag
# Processing Record 45 of Set 4 | batemans bay
# Processing Record 46 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 4 | oktyabrskiy
# Processing Record 48 of Set 4 | naze
# Processing Record 49 of Set 4 | winslow
# Processing Record 50 of Set 4 | vestmanna
# Processing Record 1 of Set 5 | aasiaat
# Processing Record 2 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 5 | dargaville
# Processing Record 4 of Set 5 | mount isa
# Processing Record 5 of Set 5 | nome
# Processing Record 6 of Set 5 | yithion
# City not found. Skipping...
# Processing Record 7 of Set 5 | isangel
# Processing Record 8 of Set 5 | ilulissat
# Processing Record 9 of Set 5 | kaeo
# Processing Record 10 of Set 5 | tuktoyaktuk
# Processing Record 11 of Set 5 | praya
# Processing Record 12 of Set 5 | mikhaylovka
# Processing Record 13 of Set 5 | kushmurun
# Processing Record 14 of Set 5 | lockhart
# Processing Record 15 of Set 5 | poninka
# Processing Record 16 of Set 5 | vila velha
# Processing Record 17 of Set 5 | tiksi
# Processing Record 18 of Set 5 | rio grande
# Processing Record 19 of Set 5 | carauari
# Processing Record 20 of Set 5 | cidreira
# Processing Record 21 of Set 5 | zhumadian
# Processing Record 22 of Set 5 | torbay
# Processing Record 23 of Set 5 | castro
# Processing Record 24 of Set 5 | leh
# Processing Record 25 of Set 5 | faanui
# Processing Record 26 of Set 5 | quatre cocos
# Processing Record 27 of Set 5 | lopandino
# Processing Record 28 of Set 5 | george
# Processing Record 29 of Set 5 | bolshiye uki
# City not found. Skipping...
# Processing Record 30 of Set 5 | kruisfontein
# Processing Record 31 of Set 5 | auki
# Processing Record 32 of Set 5 | bati
# Processing Record 33 of Set 5 | kota belud
# Processing Record 34 of Set 5 | kirakira
# Processing Record 35 of Set 5 | xiamen
# Processing Record 36 of Set 5 | bandrele
# Processing Record 37 of Set 5 | moose factory
# Processing Record 38 of Set 5 | muisne
# Processing Record 39 of Set 5 | morehead
# Processing Record 40 of Set 5 | suzun
# Processing Record 41 of Set 5 | thano bula khan
# City not found. Skipping...
# Processing Record 42 of Set 5 | jeremie
# Processing Record 43 of Set 5 | kuching
# Processing Record 44 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 5 | port elizabeth
# Processing Record 46 of Set 5 | denizli
# Processing Record 47 of Set 5 | menongue
# Processing Record 48 of Set 5 | touros
# Processing Record 49 of Set 5 | zhezkazgan
# Processing Record 50 of Set 5 | pochutla
# Processing Record 1 of Set 6 | calvinia
# Processing Record 2 of Set 6 | zlobin
# Processing Record 3 of Set 6 | ribeira grande
# Processing Record 4 of Set 6 | saskylakh
# Processing Record 5 of Set 6 | si satchanalai
# Processing Record 6 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 6 | san quintin
# Processing Record 8 of Set 6 | rawson
# Processing Record 9 of Set 6 | pemba
# Processing Record 10 of Set 6 | husavik
# Processing Record 11 of Set 6 | tual
# Processing Record 12 of Set 6 | atoyac
# Processing Record 13 of Set 6 | andenes
# Processing Record 14 of Set 6 | abha
# Processing Record 15 of Set 6 | doha
# Processing Record 16 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 6 | san jeronimo
# Processing Record 18 of Set 6 | ashland
# Processing Record 19 of Set 6 | vila franca do campo
# Processing Record 20 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 6 | kargil
# Processing Record 22 of Set 6 | haines junction
# Processing Record 23 of Set 6 | surgut
# Processing Record 24 of Set 6 | nelson bay
# Processing Record 25 of Set 6 | port-cartier
# Processing Record 26 of Set 6 | tevaitoa
# Processing Record 27 of Set 6 | praia
# Processing Record 28 of Set 6 | ormara
# Processing Record 29 of Set 6 | talara
# Processing Record 30 of Set 6 | airai
# Processing Record 31 of Set 6 | la ronge
# Processing Record 32 of Set 6 | bandarbeyla
# Processing Record 33 of Set 6 | quarai
# Processing Record 34 of Set 6 | porto belo
# Processing Record 35 of Set 6 | caravelas
# Processing Record 36 of Set 6 | ciudad bolivar
# Processing Record 37 of Set 6 | sobolevo
# Processing Record 38 of Set 6 | bubaque
# Processing Record 39 of Set 6 | souillac
# Processing Record 40 of Set 6 | tura
# Processing Record 41 of Set 6 | fort frances
# Processing Record 42 of Set 6 | ambilobe
# Processing Record 43 of Set 6 | lebu
# Processing Record 44 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 6 | rabaul
# Processing Record 46 of Set 6 | jalu
# Processing Record 47 of Set 6 | tiznit
# Processing Record 48 of Set 6 | inverell
# Processing Record 49 of Set 6 | gejiu
# Processing Record 50 of Set 6 | tilichiki
# Processing Record 1 of Set 7 | boulsa
# Processing Record 2 of Set 7 | delta del tigre
# Processing Record 3 of Set 7 | bogale
# Processing Record 4 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 7 | christchurch
# Processing Record 6 of Set 7 | berezovyy
# Processing Record 7 of Set 7 | natal
# Processing Record 8 of Set 7 | sakaiminato
# Processing Record 9 of Set 7 | port hardy
# Processing Record 10 of Set 7 | lazaro cardenas
# Processing Record 11 of Set 7 | kaffrine
# Processing Record 12 of Set 7 | isiro
# Processing Record 13 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 15 of Set 7 | olafsvik
# Processing Record 16 of Set 7 | progreso
# Processing Record 17 of Set 7 | taunggyi
# Processing Record 18 of Set 7 | margate
# Processing Record 19 of Set 7 | bereda
# Processing Record 20 of Set 7 | ekibastuz
# Processing Record 21 of Set 7 | wamba
# Processing Record 22 of Set 7 | bilma
# Processing Record 23 of Set 7 | aklavik
# Processing Record 24 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 7 | sorland
# Processing Record 26 of Set 7 | vao
# Processing Record 27 of Set 7 | dhidhdhoo
# Processing Record 28 of Set 7 | petropavl
# Processing Record 29 of Set 7 | lynn haven
# Processing Record 30 of Set 7 | eyl
# Processing Record 31 of Set 7 | mangan
# Processing Record 32 of Set 7 | manta
# Processing Record 33 of Set 7 | lahij
# Processing Record 34 of Set 7 | gongzhuling
# Processing Record 35 of Set 7 | chiradzulu
# Processing Record 36 of Set 7 | marondera
# Processing Record 37 of Set 7 | matay
# Processing Record 38 of Set 7 | banda aceh
# Processing Record 39 of Set 7 | vynohradivka
# Processing Record 40 of Set 7 | susehri
# Processing Record 41 of Set 7 | toora-khem
# Processing Record 42 of Set 7 | ribeira brava
# Processing Record 43 of Set 7 | brae
# Processing Record 44 of Set 7 | pierre
# Processing Record 45 of Set 7 | saldanha
# Processing Record 46 of Set 7 | broome
# Processing Record 47 of Set 7 | ust-koksa
# Processing Record 48 of Set 7 | talnakh
# Processing Record 49 of Set 7 | lagos
# Processing Record 50 of Set 7 | swan hill
# Processing Record 1 of Set 8 | sur
# Processing Record 2 of Set 8 | loves park
# Processing Record 3 of Set 8 | yakeshi
# Processing Record 4 of Set 8 | filadelfia
# Processing Record 5 of Set 8 | saint-prosper
# Processing Record 6 of Set 8 | totness
# Processing Record 7 of Set 8 | ligaya
# Processing Record 8 of Set 8 | nuqui
# Processing Record 9 of Set 8 | opuwo
# Processing Record 10 of Set 8 | kahului
# Processing Record 11 of Set 8 | klaksvik
# Processing Record 12 of Set 8 | parksville
# Processing Record 13 of Set 8 | kitzbuhel
# Processing Record 14 of Set 8 | santa rosa
# Processing Record 15 of Set 8 | arrecife
# Processing Record 16 of Set 8 | taree
# Processing Record 17 of Set 8 | geraldton
# Processing Record 18 of Set 8 | labytnangi
# Processing Record 19 of Set 8 | hami
# Processing Record 20 of Set 8 | stornoway
# Processing Record 21 of Set 8 | veraval
# Processing Record 22 of Set 8 | port moresby
# Processing Record 23 of Set 8 | ostrovnoy
# Processing Record 24 of Set 8 | chino valley
# Processing Record 25 of Set 8 | imisli
# City not found. Skipping...
# Processing Record 26 of Set 8 | batsfjord
# Processing Record 27 of Set 8 | charlestown
# Processing Record 28 of Set 8 | hervey bay
# Processing Record 29 of Set 8 | mutum
# Processing Record 30 of Set 8 | cururupu
# Processing Record 31 of Set 8 | nanortalik
# Processing Record 32 of Set 8 | biak
# Processing Record 33 of Set 8 | amahai
# Processing Record 34 of Set 8 | ambon
# Processing Record 35 of Set 8 | tabou
# Processing Record 36 of Set 8 | tautira
# Processing Record 37 of Set 8 | yar-sale
# Processing Record 38 of Set 8 | tigil
# Processing Record 39 of Set 8 | alofi
# Processing Record 40 of Set 8 | mandera
# Processing Record 41 of Set 8 | brigantine
# Processing Record 42 of Set 8 | fairbanks
# Processing Record 43 of Set 8 | vanavara
# Processing Record 44 of Set 8 | maceio
# Processing Record 45 of Set 8 | saint-augustin
# Processing Record 46 of Set 8 | comodoro rivadavia
# Processing Record 47 of Set 8 | noumea
# Processing Record 48 of Set 8 | agboville
# Processing Record 49 of Set 8 | abalak
# Processing Record 50 of Set 8 | eston
# Processing Record 1 of Set 9 | college
# Processing Record 2 of Set 9 | paraiso
# Processing Record 3 of Set 9 | namatanai
# Processing Record 4 of Set 9 | inuvik
# Processing Record 5 of Set 9 | canakkale
# Processing Record 6 of Set 9 | ugoofaaru
# Processing Record 7 of Set 9 | udachnyy
# Processing Record 8 of Set 9 | murzzuschlag
# Processing Record 9 of Set 9 | kijang
# Processing Record 10 of Set 9 | ayorou
# Processing Record 11 of Set 9 | hailun
# Processing Record 12 of Set 9 | dingle
# Processing Record 13 of Set 9 | batagay
# Processing Record 14 of Set 9 | saint-joseph
# Processing Record 15 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 9 | rio real
# Processing Record 17 of Set 9 | stromness
# Processing Record 18 of Set 9 | puerto del rosario
# Processing Record 19 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 20 of Set 9 | limon
# Processing Record 21 of Set 9 | kanye
# Processing Record 22 of Set 9 | havre-saint-pierre
# Processing Record 23 of Set 9 | kushiro
# Processing Record 24 of Set 9 | seoul
# Processing Record 25 of Set 9 | chabahar
# Processing Record 26 of Set 9 | saint anthony
# Processing Record 27 of Set 9 | morondava
# Processing Record 28 of Set 9 | araouane
# Processing Record 29 of Set 9 | tessalit
# Processing Record 30 of Set 9 | ahuimanu
# Processing Record 31 of Set 9 | mayya
# Processing Record 32 of Set 9 | atyrau
# Processing Record 33 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 34 of Set 9 | abnub
# Processing Record 35 of Set 9 | pisco
# Processing Record 36 of Set 9 | riyadh
# Processing Record 37 of Set 9 | charleston
# Processing Record 38 of Set 9 | balkanabat
# Processing Record 39 of Set 9 | derzhavinsk
# Processing Record 40 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 9 | easton
# Processing Record 42 of Set 9 | sanger
# Processing Record 43 of Set 9 | urusha
# Processing Record 44 of Set 9 | segou
# Processing Record 45 of Set 9 | gamboma
# Processing Record 46 of Set 9 | chernyshevskiy
# Processing Record 47 of Set 9 | cherskiy
# Processing Record 48 of Set 9 | berdigestyakh
# Processing Record 49 of Set 9 | ust-nera
# Processing Record 50 of Set 9 | chara
# Processing Record 1 of Set 10 | quelimane
# Processing Record 2 of Set 10 | corinto
# Processing Record 3 of Set 10 | eureka
# Processing Record 4 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of Set 10 | dori
# Processing Record 6 of Set 10 | samalkha
# Processing Record 7 of Set 10 | hualmay
# Processing Record 8 of Set 10 | phrai bung
# City not found. Skipping...
# Processing Record 9 of Set 10 | celestun
# Processing Record 10 of Set 10 | champerico
# Processing Record 11 of Set 10 | constantine
# Processing Record 12 of Set 10 | maholi
# Processing Record 13 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 14 of Set 10 | clemmons
# Processing Record 15 of Set 10 | porbandar
# Processing Record 16 of Set 10 | gushikawa
# Processing Record 17 of Set 10 | uruacu
# Processing Record 18 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 10 | kavaratti
# Processing Record 20 of Set 10 | turukhansk
# Processing Record 21 of Set 10 | porto walter
# Processing Record 22 of Set 10 | south venice
# Processing Record 23 of Set 10 | ureki
# Processing Record 24 of Set 10 | tuatapere
# Processing Record 25 of Set 10 | naco
# Processing Record 26 of Set 10 | bay roberts
# Processing Record 27 of Set 10 | yuli
# Processing Record 28 of Set 10 | chapais
# Processing Record 29 of Set 10 | maturin
# Processing Record 30 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 32 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 33 of Set 10 | sumbe
# Processing Record 34 of Set 10 | parole
# Processing Record 35 of Set 10 | mason city
# Processing Record 36 of Set 10 | avanigadda
# Processing Record 37 of Set 10 | sao joao batista
# Processing Record 38 of Set 10 | sovetskaya
# Processing Record 39 of Set 10 | huangmei
# Processing Record 40 of Set 10 | khatassy
# Processing Record 41 of Set 10 | usinsk
# Processing Record 42 of Set 10 | akdepe
# Processing Record 43 of Set 10 | kandrian
# Processing Record 44 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 45 of Set 10 | kindu
# Processing Record 46 of Set 10 | mkushi
# Processing Record 47 of Set 10 | richards bay
# Processing Record 48 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 10 | camana
# Processing Record 50 of Set 10 | novikovo
# Processing Record 1 of Set 11 | sfantu gheorghe
# Processing Record 2 of Set 11 | abadiania
# Processing Record 3 of Set 11 | balikpapan
# Processing Record 4 of Set 11 | barroquinha
# Processing Record 5 of Set 11 | lingao
# Processing Record 6 of Set 11 | wairoa
# Processing Record 7 of Set 11 | saint-denis
# Processing Record 8 of Set 11 | sisimiut
# Processing Record 9 of Set 11 | pacific grove
# Processing Record 10 of Set 11 | kloulklubed
# Processing Record 11 of Set 11 | walvis bay
# Processing Record 12 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 11 | kungurtug
# Processing Record 14 of Set 11 | trairi
# Processing Record 15 of Set 11 | chumikan
# Processing Record 16 of Set 11 | narodychi
# Processing Record 17 of Set 11 | svetlyy
# Processing Record 18 of Set 11 | hambantota
# Processing Record 19 of Set 11 | vadso
# Processing Record 20 of Set 11 | ishikawa
# Processing Record 21 of Set 11 | bac lieu
# Processing Record 22 of Set 11 | gobabis
# Processing Record 23 of Set 11 | buala
# Processing Record 24 of Set 11 | svolvaer
# Processing Record 25 of Set 11 | beitbridge
# Processing Record 26 of Set 11 | pleshanovo
# Processing Record 27 of Set 11 | tsabong
# Processing Record 28 of Set 11 | liku
# Processing Record 29 of Set 11 | hovd
# Processing Record 30 of Set 11 | mabaruma
# Processing Record 31 of Set 11 | lichinga
# Processing Record 32 of Set 11 | xucheng
# Processing Record 33 of Set 11 | grand gaube
# Processing Record 34 of Set 11 | lokken verk
# City not found. Skipping...
# Processing Record 35 of Set 11 | cayenne
# Processing Record 36 of Set 11 | alcudia
# Processing Record 37 of Set 11 | llangefni
# Processing Record 38 of Set 11 | okhotsk
# Processing Record 39 of Set 11 | aksha
# Processing Record 40 of Set 11 | ust-ishim
# Processing Record 41 of Set 11 | baijiantan
# Processing Record 42 of Set 11 | barbacena
# Processing Record 43 of Set 11 | poya
# Processing Record 44 of Set 11 | ust-omchug
# Processing Record 45 of Set 11 | dudinka
# Processing Record 46 of Set 11 | sheregesh
# Processing Record 47 of Set 11 | nouadhibou
# Processing Record 48 of Set 11 | cuamba
# Processing Record 49 of Set 11 | lasa
# Processing Record 50 of Set 11 | iquitos
# Processing Record 1 of Set 12 | gladstone
# Processing Record 2 of Set 12 | inhambane
# Processing Record 3 of Set 12 | gidole
# Processing Record 4 of Set 12 | wanaka
# Processing Record 5 of Set 12 | westport
# Processing Record 6 of Set 12 | mbarara
# Processing Record 7 of Set 12 | mubi
# Processing Record 8 of Set 12 | nanakuli
# Processing Record 9 of Set 12 | itapirapua
# Processing Record 10 of Set 12 | yeppoon
# Processing Record 11 of Set 12 | sayyan
# Processing Record 12 of Set 12 | cumana
# Processing Record 13 of Set 12 | glenwood springs
# Processing Record 14 of Set 12 | palamedu
# Processing Record 15 of Set 12 | anadyr
# Processing Record 16 of Set 12 | karratha
# Processing Record 17 of Set 12 | krasnyy oktyabr
# Processing Record 18 of Set 12 | jiwani
# Processing Record 19 of Set 12 | gallup
# Processing Record 20 of Set 12 | samarai
# Processing Record 21 of Set 12 | qaqortoq
# Processing Record 22 of Set 12 | thinadhoo
# Processing Record 23 of Set 12 | lorengau
# Processing Record 24 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 12 | malatya
# Processing Record 26 of Set 12 | takoradi
# Processing Record 27 of Set 12 | constitucion
# Processing Record 28 of Set 12 | samatau
# City not found. Skipping...
# Processing Record 29 of Set 12 | nsanje
# Processing Record 30 of Set 12 | esperance
# Processing Record 31 of Set 12 | bulgan
# Processing Record 32 of Set 12 | imeni poliny osipenko
# Processing Record 33 of Set 12 | kapit
# Processing Record 34 of Set 12 | saint-pierre
# Processing Record 35 of Set 12 | biankouma
# Processing Record 36 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 12 | fare
# Processing Record 38 of Set 12 | taoudenni
# Processing Record 39 of Set 12 | beja
# Processing Record 40 of Set 12 | fomboni
# Processing Record 41 of Set 12 | wonopringgo
# Processing Record 42 of Set 12 | tateyama
# Processing Record 43 of Set 12 | yate
# Processing Record 44 of Set 12 | dongsheng
# Processing Record 45 of Set 12 | richmond hill
# Processing Record 46 of Set 12 | chuguyevka
# Processing Record 47 of Set 12 | dongli
# Processing Record 48 of Set 12 | bonavista
# Processing Record 49 of Set 12 | labuan
# Processing Record 50 of Set 12 | yerbogachen
# Processing Record 1 of Set 13 | havelock
# Processing Record 2 of Set 13 | lephepe
# City not found. Skipping...
# Processing Record 3 of Set 13 | port blair
# Processing Record 4 of Set 13 | kapoeta
# Processing Record 5 of Set 13 | mwense
# Processing Record 6 of Set 13 | sidney
# Processing Record 7 of Set 13 | shihezi
# Processing Record 8 of Set 13 | aleksandrov gay
# Processing Record 9 of Set 13 | medea
# Processing Record 10 of Set 13 | iberia
# Processing Record 11 of Set 13 | catuday
# Processing Record 12 of Set 13 | san jose
# Processing Record 13 of Set 13 | dromolaxia
# Processing Record 14 of Set 13 | price
# Processing Record 15 of Set 13 | muscat
# Processing Record 16 of Set 13 | rumoi
# Processing Record 17 of Set 13 | bonfim
# Processing Record 18 of Set 13 | khandbari
# Processing Record 19 of Set 13 | key largo
# Processing Record 20 of Set 13 | afgoye
# City not found. Skipping...
# Processing Record 21 of Set 13 | oistins
# Processing Record 22 of Set 13 | xuddur
# Processing Record 23 of Set 13 | port-gentil
# Processing Record 24 of Set 13 | taltal
# Processing Record 25 of Set 13 | kochki
# Processing Record 26 of Set 13 | worland
# Processing Record 27 of Set 13 | rundu
# Processing Record 28 of Set 13 | kutum
# Processing Record 29 of Set 13 | maragogi
# Processing Record 30 of Set 13 | puerto escondido
# Processing Record 31 of Set 13 | yablonovo
# Processing Record 32 of Set 13 | mantua
# Processing Record 33 of Set 13 | ayan
# Processing Record 34 of Set 13 | alibunar
# Processing Record 35 of Set 13 | boueni
# Processing Record 36 of Set 13 | monrovia
# Processing Record 37 of Set 13 | poum
# Processing Record 38 of Set 13 | kabalo
# Processing Record 39 of Set 13 | gimli
# Processing Record 40 of Set 13 | port hawkesbury
# Processing Record 41 of Set 13 | nova olimpia
# Processing Record 42 of Set 13 | la asuncion
# Processing Record 43 of Set 13 | palmares do sul
# Processing Record 44 of Set 13 | cukai
# Processing Record 45 of Set 13 | aqtobe
# Processing Record 46 of Set 13 | yaan
# Processing Record 47 of Set 13 | waynesboro
# Processing Record 48 of Set 13 | indramayu
# Processing Record 49 of Set 13 | beringovskiy
# Processing Record 50 of Set 13 | san carlos
# Processing Record 1 of Set 14 | luderitz
# Processing Record 2 of Set 14 | xingyi
# Processing Record 3 of Set 14 | limbazi
# Processing Record 4 of Set 14 | boende
# Processing Record 5 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 14 | miraflores
# Processing Record 7 of Set 14 | rabo de peixe
# Processing Record 8 of Set 14 | garelochhead
# Processing Record 9 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 10 of Set 14 | mugur-aksy
# Processing Record 11 of Set 14 | tocopilla
# Processing Record 12 of Set 14 | muli
# Processing Record 13 of Set 14 | ossora
# Processing Record 14 of Set 14 | sangar
# Processing Record 15 of Set 14 | jizan
# Processing Record 16 of Set 14 | umm kaddadah
# Processing Record 17 of Set 14 | san policarpo
# Processing Record 18 of Set 14 | saint-louis
# Processing Record 19 of Set 14 | holme
# Processing Record 20 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 14 | gazanjyk
# Processing Record 22 of Set 14 | ukiah
# Processing Record 23 of Set 14 | kuandian
# Processing Record 24 of Set 14 | pyinmana
# Processing Record 25 of Set 14 | ilebo
# Processing Record 26 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 14 | yumen
# Processing Record 28 of Set 14 | birjand
# Processing Record 29 of Set 14 | bowen
# Processing Record 30 of Set 14 | sao jose da coroa grande
# Processing Record 31 of Set 14 | barra do garcas
# Processing Record 32 of Set 14 | kozhevnikovo
# Processing Record 33 of Set 14 | mogocha
# Processing Record 34 of Set 14 | manggar
# Processing Record 35 of Set 14 | paranga
# Processing Record 36 of Set 14 | varna
# Processing Record 37 of Set 14 | bloomington
# Processing Record 38 of Set 14 | mana
# Processing Record 39 of Set 14 | shenjiamen
# Processing Record 40 of Set 14 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 14 | falciu
# Processing Record 42 of Set 14 | kailua
# Processing Record 43 of Set 14 | alice springs
# Processing Record 44 of Set 14 | kharan
# Processing Record 45 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 46 of Set 14 | khotynets
# Processing Record 47 of Set 14 | tucano
# Processing Record 48 of Set 14 | yagodnoye
# Processing Record 49 of Set 14 | mitsamiouli
# Processing Record 50 of Set 14 | randfontein
# Processing Record 1 of Set 15 | miandoab
# Processing Record 2 of Set 15 | thomasville
# Processing Record 3 of Set 15 | umm lajj
# Processing Record 4 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 15 | prinos
# Processing Record 6 of Set 15 | darhan
# Processing Record 7 of Set 15 | dinguiraye
# Processing Record 8 of Set 15 | barcelos
# Processing Record 9 of Set 15 | tyrma
# Processing Record 10 of Set 15 | jinchang
# Processing Record 11 of Set 15 | bartica
# Processing Record 12 of Set 15 | bondo
# Processing Record 13 of Set 15 | rio gallegos
# Processing Record 14 of Set 15 | kotelnikovo
# Processing Record 15 of Set 15 | yenagoa
# Processing Record 16 of Set 15 | mandan
# Processing Record 17 of Set 15 | temple city
# Processing Record 18 of Set 15 | asau
# Processing Record 19 of Set 15 | baley
# Processing Record 20 of Set 15 | neiafu
# Processing Record 21 of Set 15 | locri
# Processing Record 22 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 15 | severobaykalsk
# Processing Record 24 of Set 15 | marsh harbour
# Processing Record 25 of Set 15 | beinamar
# Processing Record 26 of Set 15 | phalaborwa
# Processing Record 27 of Set 15 | tarsus
# Processing Record 28 of Set 15 | raigarh
# Processing Record 29 of Set 15 | listvyanskiy
# Processing Record 30 of Set 15 | dera bugti
# Processing Record 31 of Set 15 | sioni
# Processing Record 32 of Set 15 | moyale
# Processing Record 33 of Set 15 | bell ville
# Processing Record 34 of Set 15 | kudahuvadhoo
# Processing Record 35 of Set 15 | joshimath
# Processing Record 36 of Set 15 | dolores
# Processing Record 37 of Set 15 | bayburt
# Processing Record 38 of Set 15 | moss vale
# Processing Record 39 of Set 15 | menzelinsk
# Processing Record 40 of Set 15 | coos bay
# Processing Record 41 of Set 15 | moerai
# Processing Record 42 of Set 15 | port hedland
# Processing Record 43 of Set 15 | kiri buru
# Processing Record 44 of Set 15 | plon
# Processing Record 45 of Set 15 | igarka
# Processing Record 46 of Set 15 | peterhead
# Processing Record 47 of Set 15 | tel aviv-yafo
# Processing Record 48 of Set 15 | oranjemund
# Processing Record 49 of Set 15 | padang
# Processing Record 50 of Set 15 | puerto carreno
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 690

# %%
# 6.2.7


# Convert the array of dictionaries to a Pandas DataFrame.
# Add the data to a new DataFrame.


city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Mpika      ZM -11.8343   31.4529     72.34        33          80
# 1       Hamilton      US  39.1834  -84.5333     72.84        78           0
# 2        Te Anau      NZ -45.4167  167.7167     50.11        86          48
# 3    Yellowknife      CA  62.4560 -114.3525     48.72        87          75
# 4        Kurchum      KZ  48.5722   83.6542     69.57        20           0
# 5      Jamestown      US  42.0970  -79.2353     69.71        62           0
# 6  Ciudad Valles      MX  21.9833  -99.0167     73.40        97         100
# 7         Namibe      AO -15.1961   12.1522     62.11        82          83
# 8         Fernie      CA  49.5000 -115.0687     50.20        51         100
# 9      Busselton      AU -33.6500  115.3333     57.63        63          75
#
#    Wind Speed
# 0        9.06
# 1        8.05
# 2        4.99
# 3        3.44
# 4        4.05
# 5        9.22
# 6        4.21
# 7        6.15
# 8        2.17
# 9       20.09

# %%
import csv

# %%
# Export the DataFrame as WeatherPy_Database.csv into the Weather_Database folder (5 pt)

# create output file
output_data_file = "city_data.csv"

# Export city_data to csv
city_data_df.to_csv(output_data_file, index_label = "WeatherPy_Database")

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", ]]
cities_weather_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mpika      ZM -11.8343   31.4529     72.34        33          80
# 1     Hamilton      US  39.1834  -84.5333     72.84        78           0
# 2      Te Anau      NZ -45.4167  167.7167     50.11        86          48
# 3  Yellowknife      CA  62.4560 -114.3525     48.72        87          75
# 4      Kurchum      KZ  48.5722   83.6542     69.57        20           0
#
#    Wind Speed
# 0        9.06
# 1        8.05
# 2        4.99
# 3        3.44
# 4        4.05

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
